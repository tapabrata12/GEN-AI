# %% [markdown]
# # **LangGraph Prompts**

# %%
from dotenv import load_dotenv
import os
load_dotenv()
from langchain_groq import ChatGroq
from langchain_core.prompts import ChatPromptTemplate
if os.environ['GROQ_API_KEY']:
    print("GROQ_API_KEY is set.")
else:
    raise ValueError("GROQ_API_KEY is not set. Please set it in your .env file.")
# Out:
# GROQ_API_KEY is set.

# %%
llm = ChatGroq(model='meta-llama/llama-4-scout-17b-16e-instruct', temperature=0.5)
llm
# Out:
# ChatGroq(profile={'max_input_tokens': 131072, 'max_output_tokens': 8192, 'image_inputs': True, 'audio_inputs': False, 'video_inputs': False, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': True}, client=<groq.resources.chat.completions.Completions object at 0x000001B50CEFC7D0>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x000001B50CEFD1D0>, model_name='meta-llama/llama-4-scout-17b-16e-instruct', temperature=0.5, model_kwargs={}, groq_api_key=SecretStr('**********'))

# %%
prompt = ChatPromptTemplate([("system", "You are a helpful assistant."), ("user", "{input}")])

# %% [markdown]
# ## **Chains**

# %%
chain = prompt | llm
result = chain.invoke({"input": "What is the capital of France?"})

# %%
result
# Out:
# AIMessage(content='The capital of France is Paris.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 8, 'prompt_tokens': 28, 'total_tokens': 36, 'completion_time': 0.018841675, 'completion_tokens_details': None, 'prompt_time': 0.00015633, 'prompt_tokens_details': None, 'queue_time': 0.052265555, 'total_time': 0.018998005}, 'model_name': 'meta-llama/llama-4-scout-17b-16e-instruct', 'system_fingerprint': 'fp_37da608fc1', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019e36a8-727b-79c0-a912-11f8b27ed5ad-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 28, 'output_tokens': 8, 'total_tokens': 36})
